# %% [markdown]
# <a href="https://colab.research.google.com/github/ssemper/NLD2022/blob/main/Nonlinear_Lab_2_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=ovJcsL7vyrk

# %% [markdown]
# # Logistic Map

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def logistic(r, x):
    return r * x * (1 - x)

# %%
x = np.linspace(0,1,100)

# %%
r = 2.5

# %%
R = np.linspace(0.5,4.0,10)

# %%
R
# Out:
# array([0.5       , 0.88888889, 1.27777778, 1.66666667, 2.05555556,
#        2.44444444, 2.83333333, 3.22222222, 3.61111111, 4.        ])

# %%
for r in R:
    y = logistic(r,x)
    plt.plot(x,y)
    plt.plot(x,x)
    plt.show()

# %%
x = 0.5

# %%
r = 3.5 #Try these other values 2.8, 3.2, 3.5, 3.8, 3.9

# %%
x = logistic(r, x)

# %%
x
# Out:
# 0.875

# %%
for i in range(30):

    plt.plot(i,x,'b.',markersize=8)

    x = logistic(r, x)

# %% [markdown]
# #Vectorized Logistic Map

# %%
n = 10 #Number of different r values to test at once
r = np.linspace(2.5, 4.0, n) #Generates 10 values from 2.5, to 4.0)

# %%
x = 1e-5 * np.ones(n) #Each population initialized to the the same small starting value

# %%
x
# Out:
# array([1.e-05, 1.e-05, 1.e-05, 1.e-05, 1.e-05, 1.e-05, 1.e-05, 1.e-05,
#        1.e-05, 1.e-05])

# %%
r
# Out:
# array([2.5       , 2.66666667, 2.83333333, 3.        , 3.16666667,
#        3.33333333, 3.5       , 3.66666667, 3.83333333, 4.        ])

# %%
iterations = 30

# %%
x = logistic(r, x)

# %%
x.shape
# Out:
# (10,)

# %%
x
# Out:
# array([2.499975e-05, 2.666640e-05, 2.833305e-05, 2.999970e-05,
#        3.166635e-05, 3.333300e-05, 3.499965e-05, 3.666630e-05,
#        3.833295e-05, 3.999960e-05])

# %%
X = np.zeros((iterations,n)) # Create matrix to store x point at each iteration and for each value of r

# %%
for i in range(1,iterations):
    
    x = logistic(r, x) 

    X[i,:] = x

# %%
plt.plot(X[:,[1]])

# %%
X.shape
# Out:
# (30, 10)

# %%
plt.plot(X[:,3],'.')

# %%
plt.plot(X[:,:5])

# %%
plt.plot(X[:,5:10])

# %%
for i in range(n):
    plt.plot(X[:,i],'.')
    plt.title('r = ' + str(r[i]))
    plt.show()

# %% [markdown]
# # Logistic Map Part 2: Poincaré Plots, Bifurcation Diagrams, and Cobweb Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def logistic(r, x):
    return r * x * (1 - x)

# %%
n = 100
r = np.linspace(2.5, 4.0, n)

# %%
x = 1e-5 * np.ones(n)

# %%
iterations = 15000

# %%
x = logistic(r, x)

# %%
X = np.zeros((iterations,n))

# %%
for i in range(1,iterations):
    
    x = logistic(r, x) 

    X[i,:] = x

# %%
plt.plot(X[:,[1]])

# %%
plt.plot(X[:,80],'.')

# %%
r[80]
# Out:
# 3.712121212121212

# %%
n1 = 96

# %%
r[n1]
# Out:
# 3.9545454545454546

# %% [markdown]
# # Poincaré Plots

# %%
X.shape
# Out:
# (15000, 100)

# %%
X[0:-1,n1] #Skip last value
# Out:
# array([0.00000000e+00, 1.56376550e-04, 6.18301470e-04, ...,
#        4.87755913e-02, 1.83477199e-01, 5.92443569e-01])

# %%
X[1:,n1] #Skip first value
# Out:
# array([1.56376550e-04, 6.18301470e-04, 2.44358946e-03, ...,
#        1.83477199e-01, 5.92443569e-01, 9.54841556e-01])

# %%
plt.plot(X[0:-1,n1],X[1:,n1],'.')

# %%
X.shape
# Out:
# (15000, 100)

# %%
X1 = np.random.random(X.shape)

# %%
plt.plot(X1[0:-1,n1],X1[1:,n1],'.')

# %% [markdown]
# # Bifurcation Diagrams

# %%
n = 100
r = np.linspace(2.5, 4.0, n)

# %%
x = 1e-5 * np.ones(n)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,10))
ax1.plot(r, x, '.', alpha=.25,markersize=10)

# %%
iterations = 100

# %%
x = logistic(r, x)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,10))
ax1.plot(r, x, '.', alpha=.25, markersize=10)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,10))

for i in range(1,iterations):

    x = logistic(r, x)

    ax1.plot(r, x, '.b', alpha = (i + 1) / iterations)

# %% [markdown]
# # Cobweb Plots

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/e/ed/LogisticCobwebChaos.gif'>
#
# An animated cobweb diagram of the logistic map $y = r x (1-x)$, showing chaotic behaviour for most values of $r > 3.57$.

# %%
x = np.linspace(0, 1)
fig, ax = plt.subplots(1, 1)
ax.plot(x, logistic(2, x), 'k')

# %%
def plot_system(r, x0, n):
    
    t = np.linspace(0, 1)

    fig, ax = plt.subplots(1, 1, figsize=(10, 10))
    ax.plot(t, logistic(r, t), 'k', lw=2)
    ax.plot([0, 1], [0, 1], 'k', lw=2)

    x = x0
    for i in range(n):
        
        y = logistic(r, x)

        ax.plot([x, x], [x, y], 'k', lw=1)
        ax.plot([x, y], [y, y], 'k', lw=1)
        ax.plot([x], [y], 'ok', ms=10, alpha=(i + 1) / n)

        x = y

    
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_title(f"$r={r:.1f}, \, x_0={x0:.1f}$")

# %%
plot_system(2.6, .1, 10)

# %%
plot_system(3.2, .1, 10)

# %%
plot_system(3.9, .1, 10)
